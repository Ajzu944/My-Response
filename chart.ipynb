# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("employees_cleaned.csv")
df.head()
# Out:
#    EmployeeID FirstName LastName Department         DOB  \
# 0        1001      John      Doe         IT  1990-05-10
# 1        1002      Sara      Lee         HR         NaN
# 2        1003      Mike    Smith    FINANCE         NaN
# 3        1004      Lisa  Johnson         IT         NaN
# 4        1005     David    Brown  MARKETING         NaN
#
#                     Email         Phone  Salary         City
# 0      john.doe@gmail.com    9812345671   50000     New York
# 1      sara.lee@gmail.com    9812345672   55000  Los Angeles
# 2    mike.smith@gmail.com    9812345673   60000      Chicago
# 3  lisa.johnson@gmail.com  919812345674   52000      Houston
# 4   david.brown@gmail.com    9812345675   58000      Phoenix

# %%
#average salary per department
avg_salary = df.groupby('Department')['Salary'].mean().sort_values(ascending=False)
plt.figure(figsize=(8,5))
plt.bar(avg_salary.index, avg_salary.values, color='red')
plt.title('Average Salary per Department')
plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.show()

# %%
# Seaborn countplot for number of employees per department
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Department', palette='Set2')
plt.title('Number of Employees per Department')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\ajzu9\AppData\Local\Temp\ipykernel_10564\1430162791.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Department', palette='Set2')
